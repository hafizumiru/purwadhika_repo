# %%
from google.oauth2 import service_account
import pandas as pd
import pandas_gbq
import seaborn as sns

superstore_data = pd.read_excel('sales-superstore-activation.xlsx')
superstore_data.rename(columns={'Feedback?': 'Feedback'}, inplace=True)
project_id = 'pro-tracker-320503'
dataset_id = 'superstore_dataset'
table_name = 'order_data'
key_path = r'D:\PurwadhikaBackup\keys\pro-tracker-320503-f5db34e449aa.json'

scopes = ['https://www.googleapis.com/auth/bigquery']
credentials = service_account.Credentials.from_service_account_file(
    key_path, scopes=scopes)

pandas_gbq.to_gbq(superstore_data,
                  f'{dataset_id}.{table_name}',
                  project_id=project_id,
                  if_exists='replace',
                  credentials=credentials
                  )
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]

# %%
sql_query = f'SELECT * FROM {project_id}.{dataset_id}.{table_name} LIMIT 10'

pandas_gbq.read_gbq(sql_query, project_id=project_id, credentials=credentials)
# Out:
# Downloading: 100%|██████████|
#           Order ID Order Date   Customer Name Country    State     City  \
# 0  BN-2014-4902106 2014-01-23    Oscar Serena   Italy  Abruzzi   Chieti
# 1  AZ-2011-2445910 2011-09-30  Susan Williams   Italy  Abruzzi  Pescara
# 2  AZ-2012-9926323 2012-01-12     Julie Ochoa   Italy  Abruzzi  Pescara
# 3  AZ-2012-9926323 2012-01-12     Julie Ochoa   Italy  Abruzzi  Pescara
# 4  AZ-2012-9926323 2012-01-12     Julie Ochoa   Italy  Abruzzi  Pescara
# 5  AZ-2012-9926323 2012-01-12     Julie Ochoa   Italy  Abruzzi  Pescara
# 6  AZ-2014-9712649 2014-07-11     Zoe Lanigan   Italy  Abruzzi  Pescara
# 7  AZ-2014-1111012 2014-09-03    Lloyd Barnes   Italy  Abruzzi  Pescara
# 8  AZ-2014-1111012 2014-09-03    Lloyd Barnes   Italy  Abruzzi  Pescara
# 9  AZ-2014-7973944 2014-09-04      Juan Smith   Italy  Abruzzi  Pescara
#
#   Region      Segment  Ship Mode         Category Sub-Category  \
# 0  South     Consumer  Immediate        Furniture  Furnishings
# ...
