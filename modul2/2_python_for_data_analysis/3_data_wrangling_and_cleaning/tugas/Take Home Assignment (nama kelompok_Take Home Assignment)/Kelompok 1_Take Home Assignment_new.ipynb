# %%
import pandas as pd

# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_columns')

# %%
df = pd.read_csv('/Users/fikrimaulana/Downloads/hotel_bookings 2.csv')
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
# 5                        27                          1
# 6                        27                          1
# 7                        27                          1
# 8                        27                          1
# 9                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
# 5                        0                     2       2  ...    No Deposit
# 6                        0                     2       2  ...    No Deposit
# 7                        0                     2       2  ...    No Deposit
# 8                        0                     3       2  ...    No Deposit
# 9                        0                     3       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type    adr  \
# 0    NaN     NaN                    0     Transient    0.0
# 1    NaN     NaN                    0     Transient    0.0
# 2    NaN     NaN                    0     Transient   75.0
# 3  304.0     NaN                    0     Transient   75.0
# 4  240.0     NaN                    0     Transient   98.0
# 5  240.0     NaN                    0     Transient   98.0
# 6    NaN     NaN                    0     Transient  107.0
# 7  303.0     NaN                    0     Transient  103.0
# 8  240.0     NaN                    0     Transient   82.0
# 9   15.0     NaN                    0     Transient  105.5
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
# 5                            0                          1           Check-Out
# 6                            0                          0           Check-Out
# 7                            0                          1           Check-Out
# 8                            0                          1            Canceled
# 9                            0                          0            Canceled
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
# 5              2015-07-03
# 6              2015-07-03
# 7              2015-07-03
# 8              2015-05-06
# 9              2015-04-22
#
# [10 rows x 32 columns]

# %%
df.shape[0]
# Out:
# 119390

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  object
# dtypes: float64(4), int64(16), object(12)
# memory usage: 29.1+ MB

# %% [markdown]
# # Data Cleaning for Hotel Bookings
#
# ## 1. Kolom yang Dihapus
# Beberapa kolom tidak relevan atau tidak digunakan dalam analisis ini, sehingga akan dihapus untuk menyederhanakan dataset:
#
# - **arrival_date_week_number**: Kolom ini dihapus karena tanggal kedatangan sudah diketahui dari kolom lain.
# - **distribution_channel**: Kolom ini dihapus karena `market_segment` memberikan detail yang lebih tentang user yang memesan.
# - **previous_bookings_not_canceled**: Tidak digunakan dalam analisis.
# - **booking_changes**: Tidak digunakan dalam analisis.
# - **agent**: Kolom ini dihapus karena terlalu banyak nilai null.
# - **company**: Dihapus karena terlalu banyak data null.
# - **required_car_parking_spaces**: Tidak digunakan untuk analisis.
# - **total_of_special_requests**: Tidak digunakan untuk analisis.
# - **reservation_status_date**: Dihapus karena tanggal reservasi sudah dapat diketahui dari kolom lain seperti `arrival_date_year`, `arrival_date_month`, dan `arrival_date_day_of_month`.
#
# ## 2. Gabungkan Kolom `children` dan `babies`
# Dikarenakan pemesanan hotel hanya melibatkan opsi dewasa dan anak-anak, maka kolom `children` dan `babies` akan digabung menjadi satu kolom baru dengan nama `children`. Nilai null pada kolom ini akan diisi dengan 0.
#
# ## 3. Hapus Baris Berdasarkan Kondisi
# ### Baris dengan `previous_cancellations` > 0
# Baris dengan nilai pada kolom `previous_cancellations` lebih dari 0 akan dihapus untuk menghindari duplikasi data.
#
# ### Baris dengan `days_in_waiting_list` > 31
# Kolom ini merepresentasikan lamanya waktu menunggu dalam daftar tunggu. Data yang menunjukkan waktu tunggu lebih dari satu bulan (> 31 hari) akan dihapus karena dianggap tidak realistis.
#
# ## 4. Hapus Baris Null pada Kolom `country`
# Beberapa baris pada kolom `country` memiliki nilai null. Karena jumlahnya sedikit, baris ini akan dihapus karena tidak terlalu mempengaruhi analisis secara keseluruhan.
#
# ---
#
# Langkah-langkah pembersihan data ini akan menghasilkan dataset yang lebih rapi dan relevan untuk analisis lebih lanjut.

# %%
kolom_dihapus = ['arrival_date_week_number', 'distribution_channel', 'previous_bookings_not_canceled', 'booking_changes',
                 'agent', 'company', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status_date']
df.drop(columns=kolom_dihapus, inplace=True, errors='ignore')
print("Setelah menghapus kolom tidak relevan:")
display(df.head(10))
# Out:
# Setelah menghapus kolom tidak relevan:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
# 5                          1                        0                     2
# 6                          1                        0                     2
# 7                          1                        0                     2
# 8                          1                        0                     3
# 9                          1                        0                     3
#
#    adults  children  ...  market_segment is_repeated_guest  \
# 0       2       0.0  ...          Direct                 0
# 1       2       0.0  ...          Direct                 0
# 2       1       0.0  ...          Direct                 0
# 3       1       0.0  ...       Corporate                 0
# 4       2       0.0  ...       Online TA                 0
# 5       2       0.0  ...       Online TA                 0
# 6       2       0.0  ...          Direct                 0
# 7       2       0.0  ...          Direct                 0
# 8       2       0.0  ...       Online TA                 0
# 9       2       0.0  ...   Offline TA/TO                 0
#
#   previous_cancellations reserved_room_type  assigned_room_type  deposit_type  \
# 0                      0                  C                   C    No Deposit
# 1                      0                  C                   C    No Deposit
# 2                      0                  A                   C    No Deposit
# 3                      0                  A                   A    No Deposit
# 4                      0                  A                   A    No Deposit
# 5                      0                  A                   A    No Deposit
# 6                      0                  C                   C    No Deposit
# 7                      0                  C                   C    No Deposit
# 8                      0                  A                   A    No Deposit
# 9                      0                  D                   D    No Deposit
#
#   days_in_waiting_list customer_type    adr  reservation_status
# 0                    0     Transient    0.0           Check-Out
# 1                    0     Transient    0.0           Check-Out
# 2                    0     Transient   75.0           Check-Out
# 3                    0     Transient   75.0           Check-Out
# 4                    0     Transient   98.0           Check-Out
# 5                    0     Transient   98.0           Check-Out
# 6                    0     Transient  107.0           Check-Out
# 7                    0     Transient  103.0           Check-Out
# 8                    0     Transient   82.0            Canceled
# 9                    0     Transient  105.5            Canceled
#
# [10 rows x 23 columns]

# %%
df['children'] = df[['children', 'babies']].fillna(0).sum(axis=1).astype(int)
df.drop(columns='babies', inplace=True)
display(df.head(10))
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
# 5                          1                        0                     2
# 6                          1                        0                     2
# 7                          1                        0                     2
# 8                          1                        0                     3
# 9                          1                        0                     3
#
#    adults  children  ... market_segment is_repeated_guest  \
# 0       2         0  ...         Direct                 0
# 1       2         0  ...         Direct                 0
# 2       1         0  ...         Direct                 0
# 3       1         0  ...      Corporate                 0
# 4       2         0  ...      Online TA                 0
# 5       2         0  ...      Online TA                 0
# 6       2         0  ...         Direct                 0
# 7       2         0  ...         Direct                 0
# 8       2         0  ...      Online TA                 0
# 9       2         0  ...  Offline TA/TO                 0
#
#   previous_cancellations  reserved_room_type  assigned_room_type deposit_type  \
# 0                      0                   C                   C   No Deposit
# 1                      0                   C                   C   No Deposit
# 2                      0                   A                   C   No Deposit
# 3                      0                   A                   A   No Deposit
# 4                      0                   A                   A   No Deposit
# 5                      0                   A                   A   No Deposit
# 6                      0                   C                   C   No Deposit
# 7                      0                   C                   C   No Deposit
# 8                      0                   A                   A   No Deposit
# 9                      0                   D                   D   No Deposit
#
#   days_in_waiting_list customer_type    adr reservation_status
# 0                    0     Transient    0.0          Check-Out
# 1                    0     Transient    0.0          Check-Out
# 2                    0     Transient   75.0          Check-Out
# 3                    0     Transient   75.0          Check-Out
# 4                    0     Transient   98.0          Check-Out
# 5                    0     Transient   98.0          Check-Out
# 6                    0     Transient  107.0          Check-Out
# 7                    0     Transient  103.0          Check-Out
# 8                    0     Transient   82.0           Canceled
# 9                    0     Transient  105.5           Canceled
#
# [10 rows x 22 columns]

# %%
df = df[df['previous_cancellations'] == 0]
display(df.head(10))
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
# 5                          1                        0                     2
# 6                          1                        0                     2
# 7                          1                        0                     2
# 8                          1                        0                     3
# 9                          1                        0                     3
#
#    adults  children  ... market_segment is_repeated_guest  \
# 0       2         0  ...         Direct                 0
# 1       2         0  ...         Direct                 0
# 2       1         0  ...         Direct                 0
# 3       1         0  ...      Corporate                 0
# 4       2         0  ...      Online TA                 0
# 5       2         0  ...      Online TA                 0
# 6       2         0  ...         Direct                 0
# 7       2         0  ...         Direct                 0
# 8       2         0  ...      Online TA                 0
# 9       2         0  ...  Offline TA/TO                 0
#
#   previous_cancellations  reserved_room_type  assigned_room_type deposit_type  \
# 0                      0                   C                   C   No Deposit
# 1                      0                   C                   C   No Deposit
# 2                      0                   A                   C   No Deposit
# 3                      0                   A                   A   No Deposit
# 4                      0                   A                   A   No Deposit
# 5                      0                   A                   A   No Deposit
# 6                      0                   C                   C   No Deposit
# 7                      0                   C                   C   No Deposit
# 8                      0                   A                   A   No Deposit
# 9                      0                   D                   D   No Deposit
#
#   days_in_waiting_list customer_type    adr reservation_status
# 0                    0     Transient    0.0          Check-Out
# 1                    0     Transient    0.0          Check-Out
# 2                    0     Transient   75.0          Check-Out
# 3                    0     Transient   75.0          Check-Out
# 4                    0     Transient   98.0          Check-Out
# 5                    0     Transient   98.0          Check-Out
# 6                    0     Transient  107.0          Check-Out
# 7                    0     Transient  103.0          Check-Out
# 8                    0     Transient   82.0           Canceled
# 9                    0     Transient  105.5           Canceled
#
# [10 rows x 22 columns]

# %%
df = df[df['days_in_waiting_list'] <= 31]
display(df.head(10))
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
# 5                          1                        0                     2
# 6                          1                        0                     2
# 7                          1                        0                     2
# 8                          1                        0                     3
# 9                          1                        0                     3
#
#    adults  children  ... market_segment is_repeated_guest  \
# 0       2         0  ...         Direct                 0
# 1       2         0  ...         Direct                 0
# 2       1         0  ...         Direct                 0
# 3       1         0  ...      Corporate                 0
# 4       2         0  ...      Online TA                 0
# 5       2         0  ...      Online TA                 0
# 6       2         0  ...         Direct                 0
# 7       2         0  ...         Direct                 0
# 8       2         0  ...      Online TA                 0
# 9       2         0  ...  Offline TA/TO                 0
#
#   previous_cancellations  reserved_room_type  assigned_room_type deposit_type  \
# 0                      0                   C                   C   No Deposit
# 1                      0                   C                   C   No Deposit
# 2                      0                   A                   C   No Deposit
# 3                      0                   A                   A   No Deposit
# 4                      0                   A                   A   No Deposit
# 5                      0                   A                   A   No Deposit
# 6                      0                   C                   C   No Deposit
# 7                      0                   C                   C   No Deposit
# 8                      0                   A                   A   No Deposit
# 9                      0                   D                   D   No Deposit
#
#   days_in_waiting_list customer_type    adr reservation_status
# 0                    0     Transient    0.0          Check-Out
# 1                    0     Transient    0.0          Check-Out
# 2                    0     Transient   75.0          Check-Out
# 3                    0     Transient   75.0          Check-Out
# 4                    0     Transient   98.0          Check-Out
# 5                    0     Transient   98.0          Check-Out
# 6                    0     Transient  107.0          Check-Out
# 7                    0     Transient  103.0          Check-Out
# 8                    0     Transient   82.0           Canceled
# 9                    0     Transient  105.5           Canceled
#
# [10 rows x 22 columns]

# %%
df = df.dropna(subset=['country'])
display(df.head(10))
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
# 5                          1                        0                     2
# 6                          1                        0                     2
# 7                          1                        0                     2
# 8                          1                        0                     3
# 9                          1                        0                     3
#
#    adults  children  ... market_segment is_repeated_guest  \
# 0       2         0  ...         Direct                 0
# 1       2         0  ...         Direct                 0
# 2       1         0  ...         Direct                 0
# 3       1         0  ...      Corporate                 0
# 4       2         0  ...      Online TA                 0
# 5       2         0  ...      Online TA                 0
# 6       2         0  ...         Direct                 0
# 7       2         0  ...         Direct                 0
# 8       2         0  ...      Online TA                 0
# 9       2         0  ...  Offline TA/TO                 0
#
#   previous_cancellations  reserved_room_type  assigned_room_type deposit_type  \
# 0                      0                   C                   C   No Deposit
# 1                      0                   C                   C   No Deposit
# 2                      0                   A                   C   No Deposit
# 3                      0                   A                   A   No Deposit
# 4                      0                   A                   A   No Deposit
# 5                      0                   A                   A   No Deposit
# 6                      0                   C                   C   No Deposit
# 7                      0                   C                   C   No Deposit
# 8                      0                   A                   A   No Deposit
# 9                      0                   D                   D   No Deposit
#
#   days_in_waiting_list customer_type    adr reservation_status
# 0                    0     Transient    0.0          Check-Out
# 1                    0     Transient    0.0          Check-Out
# 2                    0     Transient   75.0          Check-Out
# 3                    0     Transient   75.0          Check-Out
# 4                    0     Transient   98.0          Check-Out
# 5                    0     Transient   98.0          Check-Out
# 6                    0     Transient  107.0          Check-Out
# 7                    0     Transient  103.0          Check-Out
# 8                    0     Transient   82.0           Canceled
# 9                    0     Transient  105.5           Canceled
#
# [10 rows x 22 columns]

# %% [markdown]
# MENAMBAHKAN KOLOM UNTUK KATEGORI LAMA DURASI RESERVASI

# %%
if 'lead_time' in df.columns:
    df['lead_time_category'] = pd.cut(df['lead_time'], bins=[0, 7, 30, 90, float('inf')], labels=['Last Minute', 'Short Term', 'Medium Term', 'Long Term'])
    display(df)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                    July                          1                        0
# 1                    July                          1                        0
# 2                    July                          1                        0
# 3                    July                          1                        0
# 4                    July                          1                        0
# ...                   ...                        ...                      ...
# 119385             August                         30                        2
# 119386             August                         31                        2
# 119387             August                         31                        2
# 119388             August                         31                        2
# 119389             August                         29                        2
#
#         stays_in_week_nights  adults  children  ... previous_cancellations  \
# 0                          0       2         0  ...                      0
# 1                          0       2         0  ...                      0
# 2                          1       1         0  ...                      0
# 3                          1       1         0  ...                      0
# 4                          2       2         0  ...                      0
# ...                      ...     ...       ...  ...                    ...
# 119385                     5       2         0  ...                      0
# 119386                     5       3         0  ...                      0
# 119387                     5       2         0  ...                      0
# 119388                     5       2         0  ...                      0
# 119389                     7       2         0  ...                      0
#
#        reserved_room_type assigned_room_type  deposit_type  \
# 0                       C                  C    No Deposit
# 1                       C                  C    No Deposit
# 2                       A                  C    No Deposit
# 3                       A                  A    No Deposit
# 4                       A                  A    No Deposit
# ...                   ...                ...           ...
# 119385                  A                  A    No Deposit
# 119386                  E                  E    No Deposit
# 119387                  D                  D    No Deposit
# 119388                  A                  A    No Deposit
# 119389                  A                  A    No Deposit
#
#         days_in_waiting_list customer_type     adr reservation_status  \
# 0                          0     Transient    0.00          Check-Out
# 1                          0     Transient    0.00          Check-Out
# 2                          0     Transient   75.00          Check-Out
# 3                          0     Transient   75.00          Check-Out
# 4                          0     Transient   98.00          Check-Out
# ...                      ...           ...     ...                ...
# 119385                     0     Transient   96.14          Check-Out
# 119386                     0     Transient  225.43          Check-Out
# 119387                     0     Transient  157.71          Check-Out
# 119388                     0     Transient  104.40          Check-Out
# 119389                     0     Transient  151.20          Check-Out
#
#         lead_time_category stay_duration
# 0                Long Term             0
# 1                Long Term             0
# 2              Last Minute             1
# 3               Short Term             1
# 4               Short Term             2
# ...                    ...           ...
# 119385          Short Term             7
# 119386           Long Term             7
# 119387         Medium Term             7
# 119388           Long Term             7
# 119389           Long Term             9
#
# [109966 rows x 24 columns]

# %% [markdown]
# MENAMBAHKAN KOLOM UNTUK DURASI MENGINAP

# %%
if 'stays_in_weekend_nights' in df.columns and 'stays_in_week_nights' in df.columns:
    df['stay_duration'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']
    display(df)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                    July                          1                        0
# 1                    July                          1                        0
# 2                    July                          1                        0
# 3                    July                          1                        0
# 4                    July                          1                        0
# ...                   ...                        ...                      ...
# 119385             August                         30                        2
# 119386             August                         31                        2
# 119387             August                         31                        2
# 119388             August                         31                        2
# 119389             August                         29                        2
#
#         stays_in_week_nights  adults  children  ... previous_cancellations  \
# 0                          0       2         0  ...                      0
# 1                          0       2         0  ...                      0
# 2                          1       1         0  ...                      0
# 3                          1       1         0  ...                      0
# 4                          2       2         0  ...                      0
# ...                      ...     ...       ...  ...                    ...
# 119385                     5       2         0  ...                      0
# 119386                     5       3         0  ...                      0
# 119387                     5       2         0  ...                      0
# 119388                     5       2         0  ...                      0
# 119389                     7       2         0  ...                      0
#
#        reserved_room_type assigned_room_type  deposit_type  \
# 0                       C                  C    No Deposit
# 1                       C                  C    No Deposit
# 2                       A                  C    No Deposit
# 3                       A                  A    No Deposit
# 4                       A                  A    No Deposit
# ...                   ...                ...           ...
# 119385                  A                  A    No Deposit
# 119386                  E                  E    No Deposit
# 119387                  D                  D    No Deposit
# 119388                  A                  A    No Deposit
# 119389                  A                  A    No Deposit
#
#         days_in_waiting_list customer_type     adr reservation_status  \
# 0                          0     Transient    0.00          Check-Out
# 1                          0     Transient    0.00          Check-Out
# 2                          0     Transient   75.00          Check-Out
# 3                          0     Transient   75.00          Check-Out
# 4                          0     Transient   98.00          Check-Out
# ...                      ...           ...     ...                ...
# 119385                     0     Transient   96.14          Check-Out
# 119386                     0     Transient  225.43          Check-Out
# 119387                     0     Transient  157.71          Check-Out
# 119388                     0     Transient  104.40          Check-Out
# 119389                     0     Transient  151.20          Check-Out
#
#         lead_time_category stay_duration
# 0                Long Term             0
# 1                Long Term             0
# 2              Last Minute             1
# 3               Short Term             1
# 4               Short Term             2
# ...                    ...           ...
# 119385          Short Term             7
# 119386           Long Term             7
# 119387         Medium Term             7
# 119388           Long Term             7
# 119389           Long Term             9
#
# [109966 rows x 24 columns]
