# %% [markdown]
# ## Data Wrangling & Cleansing Exercise

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### 1. Import & Load Data

# %% [markdown]
# import dan load data `mpg` dari `seaborn` lalu tampilkan 5 baris teratas

# %% [markdown]
# ### 2.  Berapa jumlah baris dan kolom dalam DataFrame "mpg"? Apa tipe data dari kolom-kolom tersebut?

# %%
# (_baris, _kolom)
# Out:
# (398, 9)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            398 non-null    int64
#  1   mpg           398 non-null    float64
#  2   cylinders     398 non-null    int64
#  3   displacement  398 non-null    float64
#  4   horsepower    392 non-null    float64
#  5   weight        398 non-null    int64
#  6   acceleration  398 non-null    float64
#  7   model_year    398 non-null    int64
#  8   origin        398 non-null    int64
#  9   car_name      398 non-null    object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 31.2+ KB

# %% [markdown]
# ### 3. Berapa banyak mobil yang memiliki "mpg" lebih dari 25?

# %%
# Out:
# 158

# %% [markdown]
# ###  4. Berapa rata-rata "mpg" dan "horsepower" dari mobil dalam dataset?

# %%
# Out:
#             mpg  horsepower
# mean  23.514573  104.469388

# %% [markdown]
# ### 5. Berapa jumlah mobil dalam setiap kelompok berdasarkan negara asal ("origin")?

# %%
# Out:
#         name
# origin
# europe    70
# japan     79
# usa      249

# %% [markdown]
# ###  6. Apa nama mobil-mobil dengan "mpg" antara 20 dan 25?

# %%
# Out:
# ['toyota corona mark ii',
#  'plymouth duster',
#  'ford maverick',
#  'peugeot 504',
#  'audi 100 ls',
#  'saab 99e',
#  'amc gremlin',
#  'toyota corona',
#  'ford pinto',
#  'chevrolet vega (sw)',
#  'mercury capri 2000',
#  'toyota corona hardtop',
#  'dodge colt hardtop',
#  'volkswagen type 3',
#  'chevrolet vega',
#  'ford pinto runabout',
#  'volkswagen 411 (sw)',
#  'peugeot 504 (sw)',
#  'ford pinto (sw)',
#  'toyouta corona mark ii (sw)',
#  'plymouth duster',
#  'toyota carina',
#  'chevrolet vega',
#  'datsun 610',
#  'mercury capri v6',
#  'opel manta',
#  'audi 100ls',
#  'saab 99le',
#  'toyota mark ii',
#  'plymouth duster',
#  'ford maverick',
#  'chevrolet vega',
#  'fiat 128',
#  'honda civic',
#  'buick skyhawk',
#  'chevrolet monza 2+2',
#  'ford pinto',
#  'amc gremlin',
#  'pontiac astro',
#  'toyota corona',
#  'volkswagen dasher',
#  'datsun 710',
#  'audi 100ls',
#  'peugeot 504',
#  'volvo 244dl',
#  'saab 99le',
#  'opel 1900',
#  'capri ii',
#  'plymouth valiant',
#  'chevrolet nova',
#  'ford maverick',
#  'amc hornet',
#  'chevrolet woody',
#  'dodge aspen se',
#  'volvo 245',
#  'buick skylark',
#  'pontiac sunbird coupe',
#  'datsun 810',
#  'bmw 320i',
#  'mazda rx-4',
#  'mercury monarch ghia',
#  'chevrolet malibu',
#  'ford fairmont (auto)',
#  'plymouth volare',
#  'buick century special',
#  'mercury zephyr',
#  'toyota celica gt liftback',
#  'plymouth sapporo',
#  'oldsmobile starfire sx',
#  'datsun 200-sx',
#  'audi 5000',
#  'saab 99gle',
#  'pontiac lemans v6',
#  'ford fairmont 4',
#  'amc concord dl 6',
#  'dodge aspen 6',
#  'cadillac eldorado',
#  'oldsmobile cutlass salon brougham',
#  'amc concord',
#  'mazda rx-7 gs',
#  'ford mustang cobra',
#  'chevrolet citation',
#  'datsun 810 maxima',
#  'buick century',
#  'ford granada gl',
#  'ford fairmont futura',
#  'amc concord dl',
#  'buick century limited',
#  'ford granada l']

# %% [markdown]
# ### 7. Tampilkan 3 mobil dengan akselerasi tertinggi?

# %%
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 11  14.0          8         340.0       160.0    3609           8.0
# 7   14.0          8         440.0       215.0    4312           8.5
# 9   15.0          8         390.0       190.0    3850           8.5
#
#     model_year origin                name
# 11          70    usa  plymouth 'cuda 340
# 7           70    usa   plymouth fury iii
# 9           70    usa  amc ambassador dpl

# %% [markdown]
# ### 8. Tambahkan kolom baru dengan nama kpl yang merupakan konversi dari mpg menjadi kilometer per liter (1 mpg = 0.42514 kpl)

# %%
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name       kpl
# 0            70     usa  chevrolet chevelle malibu   7.65252
# 1            70     usa          buick skylark 320   6.37710
# 2            70     usa         plymouth satellite   7.65252
# 3            70     usa              amc rebel sst   6.80224
# 4            70     usa                ford torino   7.22738
# ..          ...     ...                        ...       ...
# 393          82     usa            ford mustang gl  11.47878
# 394          82  europe                  vw pickup  18.70616
# 395          82     usa              dodge rampage  13.60448
# 396          82     usa                ford ranger  11.90392
# 397          82     usa                 chevy s-10  13.17934
#
# [398 rows x 10 columns]

# %% [markdown]
# ###  9. Bagaimana "mpg" rata-rata berubah dari tahun ke tahun?

# %%
# Out:
# model_year
# 70         NaN
# 71    3.560345
# 72   -2.535714
# 73   -1.614286
# 74    5.603704
# 75   -2.437037
# 76    1.306863
# 77    1.801471
# 78    0.686111
# 79    1.031992
# 80    8.603448
# 81   -3.362069
# 82    1.375195
# Name: mpg, dtype: float64

# %% [markdown]
# ### 10. Temukan mobil dengan konsumsi bahan bakar ("mpg") tertinggi, dan tampilkan informasi lengkapnya.

# %%
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
#
#      model_year origin       name        kpl
# 322          80  japan  mazda glc  19.811524

# %%
# Out:
# mpg                  46.6
# cylinders               4
# displacement         86.0
# horsepower           65.0
# weight               2110
# acceleration         17.9
# model_year             80
# origin              japan
# name            mazda glc
# kpl             19.811524
# Name: 322, dtype: object

# %% [markdown]
# ###  11. Temukan mobil dengan kombinasi performa terbaik, yaitu memiliki "horsepower" tinggi, "mpg" tinggi, dan "acceleration" rendah. Tampilkan informasi lengkapnya.

# %%
# Out:
# id                             117
# mpg                           16.0
# cylinders                        8
# displacement                 400.0
# horsepower                   230.0
# weight                        4278
# acceleration                   9.5
# model_year                      73
# origin                           1
# car_name        pontiac grand prix
# kpl                        6.80224
# Name: 116, dtype: object

# %% [markdown]
# ### 12. Periksa apakah ada nilai yang hilang (missing values) dalam DataFrame "mpg", dan jika ada, tangani secara sesuai (misalnya, isi dengan nilai rata-rata).

# %%
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %% [markdown]
# ### 13. Mobil apa saja yang memiliki konsumsi bahan bakar tertinggi di setiap negara asal?

# %%
# Out:
#                            name   mpg
# origin
# europe              audi 100 ls  16.2
# japan               datsun 1200  18.0
# usa     amc ambassador brougham   9.0

# %%
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 277  16.2          6         163.0       133.0    3410          15.8
# 111  18.0          3          70.0        90.0    2124          13.5
# 28    9.0          8         304.0       193.0    4732          18.5
#
#      model_year  origin           name
# 277          78  europe  peugeot 604sl
# 111          73   japan      maxda rx3
# 28           70     usa       hi 1200d
